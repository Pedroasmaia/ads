# %% [markdown]
# # Conceitos de Orientação a Objetos
#
# - **Classes:** São abstrações que descreve entidade do mundo real.
# - **Objetos:** São as classes em instância.
# - **Instancia:** É a existeência física, em memória do objeto.
#
# Classes tem um conjunto de atributos que são comuns. Se "pessoas", fosse uma classe:
# ![image.png](attachment:image.png)
